# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as pp
import seaborn
import scipy.optimize as opt

# %%
## Test using a pandas data frame to read in 
data = pd.read_csv('F477_2019_06_Actual_Area_Methodology_By_DBA_VerizonWireless.csv')

# %%
data
# Out:
#           Unnamed: 0              DBA STATE             FIPS     2G   3G  \
# 0                  0  VerizonWireless    AK   20200001011000    0.0  0.0
# 1                  1  VerizonWireless    AK   20200001011001    0.0  0.0
# 2                  2  VerizonWireless    AK   20200001011002    0.0  0.0
# 3                  3  VerizonWireless    AK   20200001011003    0.0  0.0
# 4                  4  VerizonWireless    AK   20200001011004    0.0  0.0
# 5                  5  VerizonWireless    AK   20200001011005    0.0  0.0
# 6                  6  VerizonWireless    AK   20200001011006    0.0  0.0
# 7                  7  VerizonWireless    AK   20200001011007    0.0  0.0
# 8                  8  VerizonWireless    AK   20200001011008    0.0  0.0
# 9                  9  VerizonWireless    AK   20200001011009    0.0  0.0
# 10                10  VerizonWireless    AK   20200001011010    0.0  0.0
# 11                11  VerizonWireless    AK   20200001011011    0.0  0.0
# ...

# %%
mean = data['4G_LTE'].mean
print(mean)
# Out:
# <bound method Series.mean of 0         100.0
# 1         100.0
# 2         100.0
# 3         100.0
# 4         100.0
# 5         100.0
# 6         100.0
# 7         100.0
# 8         100.0
# 9         100.0
# 10        100.0
# 11        100.0
# 12        100.0
# 13        100.0
# 14        100.0
# 15        100.0
# 16        100.0
# 17        100.0
# 18        100.0
# 19        100.0
# 20        100.0
# 21        100.0
# 22        100.0
# 23        100.0
# 24        100.0
# 25        100.0
# 26        100.0
# 27        100.0
# 28        100.0
# 29        100.0
#           ...
# 587641    100.0
# 587642    100.0
# 587643    100.0
# 587644    100.0
# 587645    100.0
# 587646    100.0
# 587647    100.0
# 587648    100.0
# 587649    100.0
# 587650    100.0
# 587651    100.0
# 587652    100.0
# 587653    100.0
# 587654    100.0
# 587655    100.0
# 587656    100.0
# 587657    100.0
# 587658    100.0
# 587659    100.0
# 587660    100.0
# 587661    100.0
# 587662    100.0
# 587663    100.0
# ...
